# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
 medical_insurance= pd.read_csv(r"C:\Users\HP\Downloads\archive (16)\medical_insurance.csv")
medical_insurance.head()
# Out:
#    age  gender   bmi  children discount_eligibility     region  expenses  \
# 0   19  female  27.9         0                  yes  southwest  16884.92
# 1   18    male  33.8         1                   no  southeast   1725.55
# 2   28    male  33.0         3                   no  southeast   4449.46
# 3   33    male  22.7         0                   no  northwest  21984.47
# 4   32    male  28.9         0                   no  northwest   3866.86
#
#     premium
# 0  168.8492
# 1   17.2555
# 2   44.4946
# 3  439.6894
# 4   77.3372

# %%
#Scatter plot- axis level function
sns.scatterplot(data=medical_insurance,x='bmi',y='age')
# Out:
# <Axes: xlabel='bmi', ylabel='age'>

# %%
#rel plot- figure level function-square shape
sns.relplot(data=medical_insurance,x='bmi',y='discount_eligibility',kind='scatter')

# %%
sns.boxplot(x=medical_insurance["age"])
# Out:
# <Axes: xlabel='age'>

# %%
sns.displot(data=medical_insurance, x="expenses")

# %%
sns.displot(data=medical_insurance, x="age")

# %%
sns.displot(data=medical_insurance, x="bmi", kde=True)

# %%
sns.histplot(data=medical_insurance, x="age")
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=medical_insurance, y="age")
# Out:
# <Axes: xlabel='Count', ylabel='age'>

# %%
sns.kdeplot(data=medical_insurance, x="bmi")
# Out:
# <Axes: xlabel='bmi', ylabel='Density'>

# %%
sns.kdeplot(data=medical_insurance, y="age")
# Out:
# <Axes: xlabel='Density', ylabel='age'>

# %%
sns.kdeplot(data=medical_insurance)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(data=medical_insurance, x="bmi", hue="children", multiple="stack")
plt.show()

# %%
sns.violinplot(x=medical_insurance["age"])
# Out:
# <Axes: xlabel='age'>

# %%
sns.violinplot(data=medical_insurance, x="age", y="gender")
# Out:
# <Axes: xlabel='age', ylabel='gender'>

# %%
sns.barplot(medical_insurance, x="discount_eligibility", y="age")
# Out:
# <Axes: xlabel='discount_eligibility', ylabel='age'>

# %%
sns.barplot(medical_insurance, x="age", y="region", hue="discount_eligibility", legend=False)
# Out:
# <Axes: xlabel='age', ylabel='region'>

# %%
sns.countplot(medical_insurance, x="region")
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %%
sns.pairplot(medical_insurance)

# %%
sns.pairplot(medical_insurance, hue="age")

# %%
medical_insurance['age'].value_counts().plot(kind='pie')
